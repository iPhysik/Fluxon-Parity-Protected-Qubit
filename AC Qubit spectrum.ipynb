# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import *
from scipy import optimize
from wavefunction import *
from wavefunction.wavefunction1d import *
from wavefunction.utils import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <a id='# section 1'>$E_{01}\,vs.\,n_g$</a>

# %% [markdown]
# # section 1

# %%
from AC_qubit_func import spectrum_vs_ng

# %%
params = {'EJ':6.25,'EC':6.7,'EL':0.4,'ECL':5,'Delta_EJ':0.5}

# %%
args = {'Phi_min':-4*pi,'Phi_max':4*pi,'Qdim':6,'gridsize':30}

# %%
Q_dim = args['Qdim']
Q_list = np.arange(Q_dim)-2
# ng_list = np.linspace(np.min(Q_list),np.max(Q_list),100)
ng_list = np.linspace(-2,2,100)

# %%
Phi0=0
spectrum = spectrum_vs_ng(ng_list,Q_list,Phi0,params,args,asymEJ=True)

# %%
plt.rc('text', usetex=True)
plt.plot(spectrum[:,0],spectrum[:,1],'o-')
# plt.plot(spectrum[:,0],spectrum[:,2],'o-')
plt.title(r'$E_{01}$ vs. $n_g$, $\Phi_{ext}/\Phi_0$=%.1f'%(Phi0/pi),fontsize=28)
# Out:
# Text(0.5,1,'$E_{01}$ vs. $n_g$, $\\Phi_{ext}/\\Phi_0$=0.0')

# %%
Phi0=pi
spectrum = spectrum_vs_ng(ng_list,Q_list,Phi0,params,args,asymEJ=True)

# %%
plt.rc('text', usetex=True)
plt.plot(spectrum[:,0],spectrum[:,1],'o-')
# plt.plot(spectrum[:,0],spectrum[:,2],'o-')
plt.title(r'$E_{01}$ vs. $n_g$, $\Phi_{ext}/\Phi_0$=%.1f'%(Phi0/pi),fontsize=28)
# Out:
# Text(0.5,1,'$E_{01}$ vs. $n_g$, $\\Phi_{ext}/\\Phi_0$=1.0')

# %% [markdown]
# # $E_{01}\,vs.\,\Phi_{ext}$

# %%
from AC_qubit_func import spectrum_vs_phi0

# %%
args = {'Phi_min':-4*pi,'Phi_max':4*pi,'Qdim':6,'gridsize':30}

# %%
Q_dim = args['Qdim']
Q_list = np.arange(Q_dim)-2
ng_list = [0,0.5]
phi0_list = linspace(-2*pi,pi*2,60)

# %%
spectrum = spectrum_vs_phi0(phi0_list,Q_list,ng_list,params,args)

# %%
plt.figure(figsize=(8,6))
plt.plot(spectrum[:,0],spectrum[:,1],'.')
plt.plot(spectrum[:,0],spectrum[:,2],'.')
plt.grid("True")
plt.ylim([0,9])
plt.xticks(pi*linspace(-2,2,5))
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ([<matplotlib.axis.XTick at 0x1c04d705c88>,
#   <matplotlib.axis.XTick at 0x1c04d7050b8>,
#   <matplotlib.axis.XTick at 0x1c04d705b00>,
#   <matplotlib.axis.XTick at 0x1c04c1c8780>,
#   <matplotlib.axis.XTick at 0x1c04c1c8e48>],
#  <a list of 5 Text xticklabel objects>)
